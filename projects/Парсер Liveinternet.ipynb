# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-логики-парсера" data-toc-modified-id="Описание-логики-парсера-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание логики парсера</a></span></li><li><span><a href="#Полный-код-парсера-и-сбор-данных" data-toc-modified-id="Полный-код-парсера-и-сбор-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Полный код парсера и сбор данных</a></span></li></ul></div>

# %% [markdown]
# # Парсер данных для Liveinternet

# %% [markdown]
# В рамках одного из исследований потребовалось собрать данные о поисковых запросах для того, чтобы оценить существующую потребность в новом продукте.
# Исследование проводилось по состоянию на апрель 2023 года. В качестве основного источника данных был выбран сайт Liveinternet, поскольку он позволяет собрать полную статистику по ключевым фразам, а не только наиболее частотные ключи. Полученные данные также сопоставлялись с данными из других источников, в этом проекте присутствует только парсер для сайта Liveinternet.

# %% [markdown]
# ## Описание логики парсера

# %% [markdown]
# На сайте Liveinternet есть статистика по запросам на различные тематики. На момент сбора статистики в этом источнике есть данные со 146 922 сайтов. Статистика разбита по тематическим категориям. Для целевого исследования могла подойти категория Софт, но там собраны запросы, для которых система смогла однозначно определить тематику - ПО. Поэтому было решено собрать данные в целом, поскольку нужные нам запросы могут и не попасть в какую-либо конкретную категорию.
# Статистика на сайте расположена по страницам, которых множество в пределах выбранного периода. Нужно выгрузить статистику по поисковым запросам в единый датасет. Потребуется собрать данные за текущий год (2023), предыдущий год (2022), а также 2021 год, т.к. ситуация на российском рынке в 2022 году была сильно специфичной.

# %% [markdown]
# Импорт библиотек:

# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests as rq
import datetime as dt
import numpy as np

# %% [markdown]
# Для получения нужной статистики подходит отчет по поисковым фразам Liveinternet. Поскольку нужны данные за продолжительный период времени, выберем период - месяц и суммарные значения, все это настраивается в представлении с помощью переключателей.

# %% [markdown]
# Адрес страницы, с которой будут собираться данные:

# %%
url = "https://www.liveinternet.ru/stat/ru/queries.html?period=month"

# %% [markdown]
# Получаем данные страницы:

# %%
df = pd.read_html(url, encoding='utf-8')

# %%
print('Всего найдено таблиц:', len(df))
# Out:
# Всего найдено таблиц: 9

# %% [markdown]
# Найдем, в какой таблице хранятся нужные данные:

# %%
for i,j in enumerate(df):
    print(f'Начало таблицы {i}')
    display(j.head())
    print(f'Конец таблицы {i}')
# Out:
# Начало таблицы 0
#                                                    0  \
# 0                                                NaN
# 1  посещаемость по времени суток online за неделю...
# 2                                                NaN
# 3                                                NaN
# 4  Срезы: dzen_news ru-android uc usa ndr mobile ...
#
#                                                    1  \
# 0                                                NaN
# 1                                                NaN
# 2                                  Статистикадля PDA
# 3                                                NaN
# 4  Срезы: dzen_news ru-android uc usa ndr mobile ...
#
#                                                    2    3  \
# 0                                                NaN  NaN
# 1  Статистика сайта: ru Срезы: dzen_news ru-andro...  NaN
# 2                                                NaN  NaN
# 3                                                NaN  NaN
# 4                                                NaN  NaN
#
#                                                    4    5    6    7
# 0                                                NaN  NaN  NaN  NaN
# 1  регистрация Статистика сайта:  Забыли или не з...  NaN  NaN  NaN
# 2                                                NaN  NaN  NaN  NaN
# 3                                                NaN  NaN  NaN  NaN
# 4                                                NaN  NaN  NaN  NaN
# Конец таблицы 0
# Начало таблицы 1
#     0                  1
# 0 NaN  Статистикадля PDA
# Конец таблицы 1
# Начало таблицы 2
#     0                            1
# 0 NaN  обновлено 13 апреля в 23:59
# Конец таблицы 2
# Начало таблицы 3
#            0               1   2
# 0  << Мар 23  апрель 2023 г. NaN
# Конец таблицы 3
# Начало таблицы 4
#                                      0                                  1
# 0  отчет: переходы по поисковым фразам  по дням | по неделям | по месяцам
# Конец таблицы 4
# Начало таблицы 5
#                                      0                                    1  \
# 0  значения:среднесуточные / суммарные  значения:среднесуточные / суммарные
# 1                                  NaN                               Другие
# 2                                  NaN                              новости
# 3                                  NaN            газета чс последний номер
# 4                                  NaN                              майл ру
#
#                 2               3             4             5  \
# 0  апрель 2023 г.  апрель 2023 г.  март 2023 г.  март 2023 г.
# 1          851162           92.2%        883590         89.5%
# 2            5467            0.6%          6848          0.7%
# 3            2771            0.3%          2716          0.3%
# 4            2481            0.3%          2633          0.3%
#
#                       6                     7
# 0  в среднемза 3 месяца  в среднемза 3 месяца
# 1                  1993                 91.2%
# 2                    16                  0.7%
# 3                   9.1                  0.4%
# 4                   5.6                  0.3%
# Конец таблицы 5
# Начало таблицы 6
#                                                    0                 1
# 0                                                NaN               NaN
# 1  показать график относительных значений убрать ...  ссылка на график
# Конец таблицы 6
# Начало таблицы 7
#                                                    0
# 0  посещаемость по времени суток online за неделю...
# Конец таблицы 7
# Начало таблицы 8
#                                                    0   1
# 0  Служба поддержки: counter@corp.liveinternet.ru... NaN
# Конец таблицы 8

# %% [markdown]
# Статистика по запросам находится в таблице под номером 5, выделим ее в датафрейм `query`.

# %%
query = df[5]
print('Количество записей в таблице:', query.shape)
# Out:
# Количество записей в таблице: (15, 8)

# %% [markdown]
# В этот момент появилось ограничение по количеству записей. У меня был выбран вариант отображения по 100 записей на странице, но, по умолчанию в этой таблице на сайте Liveinternet показывается только 10 строк, даже если выбрать вариант отображения с большим количеством. Именно это количество записей можем получить за один запрос.

# %% [markdown]
# При этом требуется получить все данные за апрель, а это 26 страниц при количестве записей 10 на странице. При этом при переходе на следующую страницу в  адресной строке появляется аббревиатура `&page=2`, где число - это порядковый номер страницы. Поскольку количество страниц известно, используем это для перебора - будем поочередно увеличивать номер на 1.

# %% [markdown]
# Пропишем заготовку адреса без номера страницы и диапазон страниц. В конце строки с адресом будем поочередно добавлять номер страницы из указанного диапазона.

# %% [markdown]
# *заготовка адреса страницы без номера
# url_pages = "https://www.liveinternet.ru/stat/ru/queries.html?period=month&page="*

# %% [markdown]
# Страницы можно перебирать циклом, но нужно знать, какая цифра будет последней. Если указать фиксированное значение, то это не сработает. Каждый день количество запросов будет увеличиваться, количество страниц также будет расти, а значит, мы будем получать неполные данные.
# Выше среди полученных с сайта таблиц номер страницы не фигурирует, что логично, потому что это также динамический элемент страницы - гиперссылка. Можно было бы подставить в качестве конечного значения диапазона несуществующую страницу 99, но в нашем случае это не подходит. Это сильно замедлит сбор данных, и тогда в датасете задублируются строки, потому что алгоритм будет все время сохранять данные с последней доступной страницы. Научим парсер самостоятельно находить номер последней страницы в представлении.
# Получим код страницы сайта и определим, в каком из элементов лежит номер страницы.

# %% [markdown]
# Сделаем get-запрос и определим статус страницы:

# %%
r = rq.get(url)
r.status_code
# Out:
# 200

# %% [markdown]
# Статус 200 означает, что страница доступна, и с нее можно собирать данные. Получим код страницы:

# %%
r.text
# Out:
# '<!--DOCTYPE html-->\r\n<!--html  xml:lang="ru" lang="ru" dir="ltr"-->\r\n<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="ru" lang="ru" dir="ltr">\r\n<head>\r\n<title>статистика сайта &quot;Сайты Рунета&quot;</title>\r\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\r\n<meta http-equiv="Pragma" content="no-cache">\r\n<meta http-equiv="Expires" content="-1">\r\n<meta http-equiv="Cache-Control" content="no-cache">\r\n<link rel="shortcut icon" href="/i/fav-stat.ico" type="image/x-icon"/>\r\n<style type="text/css">\r\n.vm { color:#f7f7f7; font-size:11px; font-weight:bold;  text-transform:lowercase; text-decoration:none }\r\n.bc1 { background: #508099;}\r\n.bc2 { background: gray; color: white; width: 136px;}\r\n.bc4 { font: bold 16px;}\r\n.bc41 { font: 12px; color: gray;}\r\n.bc42 { font: bold 14px; color: white; background-color: #ff9900; padding-top: 3px;padding-bottom: 3px;padding-left: 3px; padding-right: 3px; text-decoration: none; width: 500px;}\r\n.bc5 { font: bold 11px;}\r\n.bc6o { font: bold 11px; background: gray; color: white; width: 70px; height: 18px; text-align: center; vertical-align:middle;}\r\n.bc6 { font: bold 11px; background: #f0f0f0; width: 70px; height: 18px; text-align: center; vertical-align:middle;}\r\n\r\na {color: black}\r\na:active {color: black}\r\na.replink:visited {color: #707070}\r\na.menu {text-decoration: none; padding:2px;}\r\na.menu:hover{color: #ffffff; text-decoration: none; background: #999999;}\r\n\r\ntd { font: 11px \'Arial\', \'Verdana\', sans-serif; line-height: 16px;  }\r\n\r\n.boldl2 {font: bold 18px \'Tahoma\', \'Verdana\', sans-serif; text-decoration:none color: #000066 ; line-height: 120%}\r\n.boldl3 {font: bold 11px \'Tahoma\', \'Verdana\', sans-serif; color: #000000; line-height: 140%}\r\n.boldl4 {font: bold 12px \'Tahoma\', \'Verdana\', sans-serif; color: #333399; line-height: 120%}\r\n.a1 {font: 11px; color:#0000CC; line-height: 11px}\r\n.a2 {font: 11px; color:#0000CC; line-height: 11px}\r\n.a22 {background:#bcbcbc; color:white;}\r\nTABLE.vigator {margin: 5px; padding: 0.3em 0.0em; border: 1px dashed #999999}\r\n.tooltip {display: none; z-index:10;\r\nposition:absolute; left:-1000px; top:-1000px;\r\nbackground-color: #FFB; border: 1px solid #000;\r\npadding: 5px; overflow: hidden;\r\n}\r\n\r\n</style>\r\n\r\n<script type="text/javascript">\r\nfunction cl(link)\r\n{\r\nimg = new Image();\r\nimg.src = \'http://www.liveinternet.ru/click?*\' + link;\r\n}\r\n\r\nfunction languagesSwitch(show)\r\n{\r\nlanguage_menu.style.visibility = \r\nshow == 1 || language_menu.style.visibility == \'hidden\' ? \'visible\' : \'hidden\';\r\n}\r\nnew Image().src = "//counter.yadro.ru/hit;li_stat_ru?r"+\r\nescape(document.referrer)+((typeof(screen)=="undefined")?"":\r\n";s"+screen.width+"*"+screen.height+"*"+(screen.colorDepth?\r\nscreen.colorDepth:screen.pixelDepth))+";u"+escape(document.URL)+\r\n";h"+escape(document.title.substring(0,150))+\r\n";"+Math.random();\r\n\r\n</script>\r\n\r\n<link rel="stylesheet" type="text/css" media="all" href="//i.li.ru/_sl_/style.css">\r\n<script type="text/javascript" src="//i.li.ru/_sl_/sl4.js"></script>\r\n\r\n<!--rmedia_HB: liveinternet_statistics-->\r\n<script async src="https://yastatic.net/pcode/adfox/header-bidding.js"></script>\r\n<script>\r\nvar adfoxBiddersMap = {\n    "criteo": "717767",\n    "myTarget": "763128",\n    "betweenDigital": "793538",\n    "adriver": "776589",\n    "rtbhouse": "851765",\n    "otm": "1460822",\n    "getintent": "958501"\n};\n\nadUnits = [\n    {\n        "code": "adfox_headmain",\n        "sizes": [\n            [\n                970,\n                250\n            ]\n        ],\n        "bids": [\n            {\n                "bidder": "criteo",\n                "params": {\n                    "placementId": 1337855\n                }\n            },\n            {\n                "bidder": "myTarget",\n                "params": {\n                    "placementId": 363344\n                }\n   ...

# %% [markdown]
# Номера страниц зашиты в этом куске кода:
#
# `Страницы: <span class="high current">1</span>&nbsp;&nbsp;<a href="queries.html?period=month&page=2" class="high">2</a>&nbsp;<a href="queries.html?period=month&page=3" class="high">3</a>&nbsp;...&nbsp;<a href="queries.html?period=month&page=26" class="high">26</a>&nbsp;<a href="queries.html?period=month&page=27" class="high">27</a>&nbsp;`

# %% [markdown]
# На странице сайта Liveinternet всегда отображается номер первой и последней страницы, а также некоторое количество промежуточных. Нас интересует только последняя страница, ее номер нужно передавать в качестве аргумента для `range` при создании диапазона страниц.
# Преобразуем полученный текст в дерево объектов:

# %%
soup = bs(r.text, 'html.parser')

# %%
soup
# Out:
# <!--DOCTYPE html-->
# <!--html  xml:lang="ru" lang="ru" dir="ltr"-->
# <html dir="ltr" lang="ru" xml:lang="ru" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>статистика сайта "Сайты Рунета"</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="-1" http-equiv="Expires"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <link href="/i/fav-stat.ico" rel="shortcut icon" type="image/x-icon"/>
# <style type="text/css">
# .vm { color:#f7f7f7; font-size:11px; font-weight:bold;  text-transform:lowercase; text-decoration:none }
# .bc1 { background: #508099;}
# .bc2 { background: gray; color: white; width: 136px;}
# .bc4 { font: bold 16px;}
# .bc41 { font: 12px; color: gray;}
# .bc42 { font: bold 14px; color: white; background-color: #ff9900; padding-top: 3px;padding-bottom: 3px;padding-left: 3px; padding-right: 3px; text-decoration: none; width: 500px;}
# .bc5 { font: bold 11px;}
# .bc6o { font: bold 11px; background: gray; color: white; width: 70px; height: 18px; text-align: center; vertical-align:middle;}
# .bc6 { font: bold 11px; background: #f0f0f0; width: 70px; height: 18px; text-align: center; vertical-align:middle;}
#
# a {color: black}
# a:active {color: black}
# a.replink:visited {color: #707070}
# a.menu {text-decoration: none; padding:2px;}
# a.menu:hover{color: #ffffff; text-decoration: none; background: #999999;}
#
# td { font: 11px 'Arial', 'Verdana', sans-serif; line-height: 16px;  }
#
# .boldl2 {font: bold 18px 'Tahoma', 'Verdana', sans-serif; text-decoration:none color: #000066 ; line-height: 120%}
# .boldl3 {font: bold 11px 'Tahoma', 'Verdana', sans-serif; color: #000000; line-height: 140%}
# .boldl4 {font: bold 12px 'Tahoma', 'Verdana', sans-serif; color: #333399; line-height: 120%}
# .a1 {font: 11px; color:#0000CC; line-height: 11px}
# .a2 {font: 11px; color:#0000CC; line-height: 11px}
# .a22 {background:#bcbcbc; color:white;}
# TABLE.vigator {margin: 5px; padding: 0.3em 0.0em; border: 1px dashed #999999}
# .tooltip {display: none; z-index:10;
# position:absolute; left:-1000px; top:-1000px;
# background-color: #FFB; border: 1px solid #000;
# padding: 5px; overflow: hidden;
# }
#
# </style>
# <script type="text/javascript">
# function cl(link)
# {
# img = new Image();
# img.src = 'http://www.liveinternet.ru/click?*' + link;
# }
#
# function languagesSwitch(show)
# {
# language_menu.style.visibility =
# show == 1 || language_menu.style.visibility == 'hidden' ? 'visible' : 'hidden';
# }
# new Image().src = "//counter.yadro.ru/hit;li_stat_ru?r"+
# escape(document.referrer)+((typeof(screen)=="undefined")?"":
# ";s"+screen.width+"*"+screen.height+"*"+(screen.colorDepth?
# screen.colorDepth:screen.pixelDepth))+";u"+escape(document.URL)+
# ";h"+escape(document.title.substring(0,150))+
# ";"+Math.random();
#
# </script>
# <link href="//i.li.ru/_sl_/style.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="//i.li.ru/_sl_/sl4.js" type="text/javascript"></script>
# <!--rmedia_HB: liveinternet_statistics-->
# <script async="" src="https://yastatic.net/pcode/adfox/header-bidding.js"></script>
# <script>
# var adfoxBiddersMap = {
#     "criteo": "717767",
#     "myTarget": "763128",
#     "betweenDigital": "793538",
#     "adriver": "776589",
#     "rtbhouse": "851765",
#     "otm": "1460822",
#     "getintent": "958501"
# };
#
# adUnits = [
#     {
#         "code": "adfox_headmain",
#         "sizes": [
#             [
#                 970,
#                 250
#             ]
#         ],
#         "bids": [
#             {
#                 "bidder": "criteo",
#                 "params": {
#                     "placementId": 1337855
#                 }
#             },
#             {
#                 "bidder": "myTarget",
#                 "params": {
#                     "placementId": 363344
#                 }
#             },
#             {
#                 "bidder": "betweenDigital",
#                 "params": {
#                     "placementId": 2864102
#                 }
#             },
#             {
#                 "bidder": "adriver",
#                 "params": {
#                     "placementId": "20:liveinternet_970x250_headmain"
#                 }
#             },
#             {
#                 "bidder": "rtbhouse",
#                 "params": {
#                     "placementId": "KDhMz1sXjkSj2QYfsdjY"
#                 }
#             },
#             {
#                 "bidder": "otm",
#                 "params": {
#                     "placementId": 9809
#                 }
#             },
#             {
#                 "bidder": "getintent",
#                 "params": {
#                     "placementId": "134_liveinternet.ru_desktop_adfox_headmain_970x250"
#                 }
#             }
#         ]
#     },
#     {
#         "code": "adfox_side1",
#         "sizes": [
#             [
#                 240,
#                 400
#             ]
#         ],
#         "bids": [
#             {
#                 "bidder": "criteo",
#                 "params": {
#                     "placementId": 1337844
#                 }
#             },
#             {
#                 "bidder": "myTarget",
#                 "params": {
#                     "placementId": 324206
#                 }
#             },
#             {
#                 "bidder": "betweenDigital",
#                 "params": {
#                     "placementId": 2693732
#                 }
#             },
#             {
#                 "bidder": "adriver",
#                 "params": {
#                     "placementId": "20:liveinternet_240x400_side_1"
#                 }
#             },
#             {
#                 "bidder": "rtbhouse",
#                 "params": {
#                     "placementId": "KVv9I6QDzjXx0ialSLHr"
#                 }
#             },
#             {
#                 "bidder": "otm",
#                 "params": {
#                     "placementId": 9810
#                 }
#             },
#             {
#                 "bidder": "getintent",
#                 "params": {
#                     "placementId": "134_liveinternet.ru_desktop_adfox_side1_240x400"
#                 }
#             }
#         ]
#     },
#     {
#         "code": "adfox_side2",
#         "sizes": [
#             [
#                 240,
#                 400
#             ]
#         ],
#         "bids": [
#             {
#                 "bidder": "criteo",
#                 "params": {
#                     "placementId": 1337845
#                 }
#             },
#             {
#                 "bidder": "myTarget",
#                 "params": {
#                     "placementId": 324210
#                 }
#             },
#             {
#                 "bidder": "betweenDigital",
#                 "params": {
#                     "placementId": 2693733
#                 }
#             },
#             {
#                 "bidder": "adriver",
#                 "params": {
#                     "placementId": "20:liveinternet_240x400_side_2"
#                 }
#             },
#             {
#                 "bidder": "rtbhouse",
#                 "params": {
#                     "placementId": "JRthmR1iwOrdQFc1hC85"
#                 }
#             },
#             {
#                 "bidder": "otm",
#                 "params": {
#                     "placementId": 9811
#                 }
#             },
#             {
#                 "bidder": "getintent",
#                 "params": {
#                     "placementId": "134_liveinternet.ru_desktop_adfox_side2_240x400"
#                 }
#             }
#         ]
#     },
#     {
#         "code": "adfox_head",
#         "sizes": [
#             [
#                 970,
#                 250
#             ]
#         ],
#         "bids": [
#             {
#                 "bidder": "criteo",
#                 "params": {
#                     "placementId": 1337855
#                 }
#             },
#             {
#                 "bidder": "myTarget",
#                 "params": {
#                     "placementId": 324242
#                 }
#             },
#             {
#                 "bidder": "betweenDigital",
#                 "params": {
#                     "placementId": 2693734
#                 }
#             },
#             {
#                 "bidder": "adriver",
#                 "params": {
#                     "placementId": "20:liveinternet_970x250_head"
#                 }
#             },
#             {
#                 "bidder": "rtbhouse",
#                 "params": {
#                     "placementId": "hRyV8XwftD24fRQHFcAn"
#                 }
#             },
#             {
#                 "bidder": "otm",
#                 "params": {
#                     "placementId": 9812
#                 }
#             },
#             {
#                 "bidder": "getintent",
#                 "params": {
#                     "placementId": "134_liveinternet.ru_desktop_adfox_head_970x250"
#                 }
#             }
#         ]
#     },
#     {
#         "code": "adfox_mid1",
#         "sizes": [
#             [
#                 300,
#                 250
#             ]
#         ],
#         "bids": [
#             {
#                 "bidder": "criteo",
#                 "params": {
#                     "placementId": 1337849
#                 }
#             },
#             {
#                 "bidder": "myTarget",
#                 "params": {
#                     "placementId": 324246
#                 }
#             },
#             {
#                 "bidder": "betweenDigital",
#                 "params": {
#                     "placementId": 2693745
#                 }
#             },
#             {
#                 "bidder": "adriver",
#                 "params": {
#                     "placementId": "20:liveinternet_300x250_mid_1"
#                 }
#             },
#             {
#                 "bidder": "rtbhouse",
#                 "params": {
#                     "placementId": "7ygIIcA2BKKbexpvJq3i"
#                 }
#             },
#             {
#                 "bidder": "otm",
#                 "params": {
#                     "placementId": 9813
#                 }
#             },
#             {
#                 "bidder": "getintent",
#                 "params": {
#                     "placementId": "134_liveinternet.ru_desktop_adfox_mid1_300x250"
#                 }
#             }
#         ]
#     },
#     {
#         "code": "adfox_mid2",
#         "sizes": [
#             [
#                 300,
#                 250
#             ]
#         ],
#         "bids": [
#             {
#                 "bidder": "criteo",
#                 "params": {
#                     "placementId": 1337850
#                 }
#             },
#             {
#                 "bidder": "myTarget",
#                 "params": {
#                     "placementId": 324248
#                 }
#             },
#             {
#                 "bidder": "betweenDigital",
#                 "params": {
#                     "placementId": 2693746
#                 }
#             },
#             {
#                 "bidder": "adriver",
#                 "params": {
#                     "placementId": "20:liveinternet_300x250_mid_2"
#                 }
#             },
#             {
#                 "bidder": "rtbhouse",
#                 "params": {
#                     "placementId": "l4A0eCxrRbLwcwIfyrvE"
#                 }
#             },
#             {
#                 "bidder": "otm",
#                 "params": {
#                     "placementId": 9814
#                 }
#             },
#             {
#                 "bidder": "getintent",
#                 "params": {
#                     "placementId": "134_liveinternet.ru_desktop_adfox_mid2_300x250"
#                 }
#             }
#         ]
#     },
#     {
#         "code": "adfox_bot1",
#         "sizes": [
#             [
#                 300,
#                 250
#             ]
#         ],
#         "bids": [
#             {
#                 "bidder": "criteo",
#                 "params": {
#                     "placementId": 1337852
#                 }
#             },
#             {
#                 "bidder": "myTarget",
#                 "params": {
#                     "placementId": 324266
#                 }
#             },
#             {
#                 "bidder": "betweenDigital",
#                 "params": {
#                     "placementId": 2693743
#                 }
#             },
#             {
#                 "bidder": "adriver",
#                 "params": {
#                     "placementId": "20:liveinternet_300x250_bot_1"
#                 }
#             },
#             {
#                 "bidder": "rtbhouse",
#                 "params": {
#                     "placementId": "fJ5Mi2xG6TtL0EUcXZ5R"
#                 }
#             },
#             {
#                 "bidder": "otm",
#                 "params": {
#                     "placementId": 9815
#                 }
#             },
#             {
#                 "bidder": "getintent",
#                 "params": {
#                     "placementId": "134_liveinternet.ru_desktop_adfox_bot1_300x250"
#                 }
#             }
#         ]
#     },
#     {
#         "code": "adfox_bot2",
#         "sizes": [
#             [
#                 300,
#                 250
#             ]
#         ],
#         "bids": [
#             {
#                 "bidder": "criteo",
#                 "params": {
#                     "placementId": 1337853
#                 }
#             },
#             {
#                 "bidder": "myTarget",
#                 "params": {
#                     "placementId": 324268
#                 }
#             },
#             {
#                 "bidder": "betweenDigital",
#                 "params": {
#                     "placementId": 2693744
#                 }
#             },
#             {
#                 "bidder": "adriver",
#                 "params": {
#                     "placementId": "20:liveinternet_300x250_bot_2"
#                 }
#             },
#             {
#                 "bidder": "rtbhouse",
#                 "params": {
#                     "placementId": "yO3R2cF6Rdd9vQyaNTcL"
#                 }
#             },
#             {
#                 "bidder": "otm",
#                 "params": {
#                     "placementId": 9816
#                 }
#             },
#             {
#                 "bidder": "getintent",
#                 "params": {
#                     "placementId": "134_liveinternet.ru_desktop_adfox_bot2_300x250"
#                 }
#             }
#         ]
#     },
#     {
#         "code": "adfox_botsticky",
#         "sizes": [
#             [
#                 728,
#                 90
#             ]
#         ],
#         "bids": [
#             {
#                 "bidder": "criteo",
#                 "params": {
#                     "placementId": 1337856
#                 }
#             },
#             {
#                 "bidder": "myTarget",
#                 "params": {
#                     "placementId": 324244
#                 }
#             },
#             {
#                 "bidder": "betweenDigital",
#                 "params": {
#                     "placementId": 2693747
#                 }
#             },
#             {
#                 "bidder": "adriver",
#                 "params": {
#                     "placementId": "20:liveinternet_728x90_botsticky"
#                 }
#             },
#             {
#                 "bidder": "otm",
#                 "params": {
#                     "placementId": 9817
#                 }
#             },
#             {
#                 "bidder": "getintent",
#                 "params": {
#                     "placementId": "134_liveinternet.ru_desktop_adfox_botsticky_728x90"
#                 }
#             }
#         ]
#     }
# ];
#
# var userTimeout = 1500;
#
# window.YaHeaderBiddingSettings = {
# 	biddersMap: adfoxBiddersMap,
# 	adUnits: adUnits,
# 	timeout: userTimeout
# };</script>
# <script crossorigin="anonymous" src="https://yastatic.net/pcode/adfox/loader.js"></script>
# <script async="" data-ad-client="ca-pub-9165516179791802" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# </head>
# <body alink="#FF0000" bgcolor="#FFFFFF" link="#0000EE" text="#000000" topmargin="6" vlink="#551A8B">
# <div id="uinfo" onmouseout="_sl_onmouseout();" onmouseover="_sl_onmouseover(0);" style="position:absolute;
# left:0px; top:0px; visibility: hidden; z-index=1;"></div>
# <div style="z-index:10003; position:absolute; top:0;
# right:0; float: right; border-left: #808080 1px solid;
# border-bottom: #808080 1px solid; padding: 2px; background: #F0F0F0;
# font: 11px 'Arial', 'Verdana', sans-serif;">
# <a class="menu" href="queries.html?period=month&amp;lang=ru"><b>Русский</b></a>
# <a class="menu" href="queries.html?period=month&amp;lang=en">English</a>
# <a class="menu" href="javascript:languagesSwitch(0)" onmouseover="languagesSwitch(1)"> ∇ </a>
# </div><div id="language_menu" style="visibility:hidden; z-index:10002;
# position: absolute; top:18px;
# right:0; float: right; border-left: #808080 1px solid;
# border-bottom: #808080 1px solid; padding: 8px; background: #F0F0F0;
# font: 11px 'Arial', 'Verdana', sans-serif; line-height: 175%;"><a class="menu" href="queries.html?period=month&amp;lang=ar">العربية</a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=be">Беларуская</a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=de">Deutsch</a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=en">English</a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=es">Español</a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=fr">Français</a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=he">עברית</a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=it">Italiano</a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=ja">日本語</a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=lt">Lietuvių</a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=lv">Latviešu</a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=pl">Polski</a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=pt">Português</a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=ru"><b>Русский</b></a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=tr">Türkçe</a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=uk">Українська</a><br/>
# <a class="menu" href="queries.html?period=month&amp;lang=zh">简体中文</a><br/>
# </div>
# <center>
# <div style="text-align:left; margin:5px; overflow:hidden; width:920px; font: 11px 'Arial', 'Verdana', sans-serif; font-weight:bold; line-height: 16px; ">
# <nobr><b><a href="/">LiveInternet</a>
# <span style="padding:10px">•</span>
# <a href="/rating/ru/">Рейтинг сайтов</a>
# <span style="padding:10px">•</span>
# <a href="/rating/ru/">Сайты Рунета</a>
# </b></nobr></div><script type="text/javascript"><!--
#
# _sl_init('uinfo','Search engines');
#
# var sId = "";
# var urlMasidx=1;
# var urlMas = Array();
# function _sl_UrlMake(i) {return i + ";winupload=on";}
#
# function go(s)
# {
# 	location.href = '//' + document.domain + '/stat/ru/' +
# 		s.options[s.selectedIndex].value;
# }
# function other(s)
# {
# 	if (s.selectedIndex < s.length - 1) {
# 		location.href = '//' + document.domain + '/stat/' +
# 			s.options[s.selectedIndex].value +
# 			'/queries.html?period=month';
# 	} else {
# 		if (confirm("Очистить список сайтов?"))
# 			location.href = '//' + document.domain +
# 			'/stat/ru/queries.html?period=month&action=clear_history';
# 		else
# 			s.selectedIndex = 0;
# 	}
#
# }
# function open_mins(link)
# {
# 	window.open(link, "mins", "width=680,height=480," +
# 	"scrollbars=no,toolbar=no,statusbar=no,location=no,directories=no,status=no,menubar=no");
# 	return false;
# }
# function help(link)
# {
# 	window.open(link, "help", "width=600,height=400," +
# 	"scrollbars=yes,toolbar=no,statusbar=no,location=no,directories=no,status=no,menubar=no");
# 	return false;
# }
#
# var titles = new Array();
# var tooltip;
#
# function cellOver(event)
# {
# 	if (!tooltip) tooltip = document.getElementById('tooltip');
# 	t = event.target;
# 	if (t.tagName != "TD" && t.parentNode.tagName == "TD") t = t.parentNode;
# 	if (t.tagName == "TD" && t.parentNode.rowIndex > 0 &&
# 		(t.parentNode.title || titles[t.parentNode.rowIndex])) {
# 		if (t.parentNode.title) {
# 			titles[t.parentNode.rowIndex] = t.parentNode.title;
# 			t.parentNode.title = "";
# 		}
# 		tooltip.innerHTML = titles[t.parentNode.rowIndex];
# 		tooltip.style.top = event.clientY + 2 + document.body.scrollTop;
# 		tooltip.style.left = event.clientX + 2 + document.body.scrollLeft;
# 		tooltip.style.display = "inline";
# 	} else {
# 		tooltip.style.display = "none";
# 	}
# }
#
# function cellMove(event)
# {
# 	if (tooltip) {
# 		tooltip.style.top = event.clientY + 2 + document.body.scrollTop;
# 		tooltip.style.left = event.clientX + 2 + document.body.scrollLeft;
# 	}
# }
# function cellOut(event)
# {
# 	if (tooltip) tooltip.style.display = "none";
# }
#
# //--></script>
# <!--AdFox START-->
# <!--MarTi-->
# <!--Площадка: liveinternet.ru / * / *-->
# <!--Тип баннера: Перетяжка 100%-->
# <!--Расположение: 1-->
# <div style="width:970px; height:280px; margin:5px 0 10px 0; overflow:hidden;">
# <div id="adfox_head"></div></div>
# <script>
#     window.Ya.adfoxCode.create({
#         ownerId: 254948,
#         containerId: 'adfox_head',
#         params: {
#             pp: 'noj',
#             ps: 'erxe',
#             p2: 'y',
#             puid1: '',
#             puid2: '',
#             puid3: ''
#         }
#     });
# </script>
# <!--videonow: Viqeo Sticky-->
# <script async="" src="https://cdn.viqeo.tv/js/vq_starter.js"></script> <div class="viqeo-fly-widget" data-playerid="512" data-profileid="1614"></div>
# <table border="0" cellpadding="0" cellspacing="0" width="850">
# <tbody><tr>
# <td colspan="5"></td>
# <tr>
# <td align="left" valign="top" width="150">
# <p>
# <div style="width:150px;padding:4px;">
# <a href="index.html?period=month">посещаемость</a><br/>
# <a href="hours.html?period=month">по времени суток</a><br/>
# <a href="online.html?period=month">online</a><br/>
# <a href="sum.html?period=month">за неделю и месяц</a><br/>
# <a href="summary.html?period=month">сводка</a><br/>
# <br/>
# <a href="visitors.html?period=month">размер аудитории</a><br/>
# <a href="days_pw.html?period=month">дней в неделю</a><br/>
# <a href="days_pm.html?period=month">дней в месяц</a><br/>
# <a href="compare.html?period=month">сравнение аудиторий</a><br/>
# <a href="sessions_pv.html?period=month">сессий на посетителя</a><br/>
# <a href="returns.html?period=month">возвраты</a><br/>
# <a href="hits_pv.html?period=month">просм. на посетителя</a><br/>
# <a href="hits_ps.html?period=month">просмотров за сессию</a><br/>
# <a href="durations.html?period=month">длительность сессий</a><br/>
# <br/>
# <a href="servers.html?period=month">варианты обращения</a><br/>
# <br/>
# <a href="catalogs.html?period=month">из каталогов и рейтингов</a><br/>
# <a href="socials.html?period=month">из социальных сетей</a><br/>
# <a href="searches.html?period=month">из поисковых систем</a><br/>
# <a href="queries.html?period=month"><span class="bc2">по поисковым фразам</span></a><br/>
# <br/>
# <a href="clicks.html?period=month">переходы по ссылкам</a><br/>
# <br/>
# <a href="demo.html?period=month">демография</a><br/>
# <a href="countries.html?period=month">страны</a><br/>
# <a href="countries_hits.html?period=month">страны (просмотры)</a><br/>
# <a href="regions.html?period=month">регионы России</a><br/>
# <a href="regions_hits.html?period=month">регионы (просмотры)</a><br/>
# <a href="providers.html?period=month">провайдеры</a><br/>
# <a href="languages.html?period=month">языки</a><br/>
# <a href="browsers.html?period=month">браузеры</a><br/>
# <a href="oses.html?period=month">ОС</a><br/>
# <a href="resolutions.html?period=month">разрешение</a><br/>
# <a href="colors.html?period=month">кол-во цветов</a><br/>
# <br/>
# <br/>
# <a href="edit.html?period=month">изменение описания</a><br/>
# <a href="logout.html?period=month">выход</a><br/>
# </div>
# <br/><br/>
# <table>
# <tr>
# <td>
# <img height="61" src="//i.li.ru/gg/smart.gif" width="30"/>
# </td>
# <td>
# <a href="http://pda.liveinternet.ru/stat/ru/queries.html?period=month">Статистика<br/>для PDA</a>
# </td>
# </tr></table>
# <br/>
# <br/>
# <hr/>
# <iframe frameborder="0" height="840" hspace="0" marginheight="0" marginwidth="0" scrolling="no" src="/publ/00stat500x60/011ruward/150x840.html" vspace="0" width="150"></iframe>
# <span id="banstat12_span"></span>
# <br/><br/>
# <p>
# <span id="banstat11_span"></span>
# <br/>
# </p></p></td>
# <td width="10"> </td>
# <td valign="top" width="520">
# <table border="0" cellpadding="3" cellspacing="0" width="520">
# <tr bgcolor="#cccccc"><form>
# <td><b>Статистика сайта:</b></td>
# <td align="right"><b>ru</b></td>
# <tr bgcolor="#e6e6e6"><td colspan="2">
# <a href="/help/stat/slices.html" onclick="return help(this)" target="_blank" title="справка"><img border="0" height="16" src="//i.li.ru/i/help.gif" width="16"/></a>
# <a href="edit.html?what=slices">Срезы</a>:
#
#
# <a href="queries.html?slice=dzen_news&amp;period=month">dzen_news</a>
# <a href="queries.html?slice=ru-android&amp;period=month">ru-android</a>
# <a href="queries.html?slice=uc&amp;period=month">uc</a>
# <a href="queries.html?slice=usa&amp;period=month">usa</a>
# <a href="queries.html?slice=ndr&amp;period=month">ndr</a>
# <a href="queries.html?slice=mobile&amp;period=month">mobile</a>
# <a href="queries.html?slice=desktop&amp;period=month">desktop</a>
# <a href="queries.html?slice=win10&amp;period=month">win10</a>
# <a href="queries.html?slice=winphone&amp;period=month">winphone</a>
# <a href="queries.html?slice=sputnik&amp;period=month">sputnik</a>
# <a href="queries.html?slice=crimea&amp;period=month">crimea</a>
# <a href="queries.html?slice=msk_iphone&amp;period=month">msk_iphone</a>
# <a href="queries.html?slice=msk_andr&amp;period=month">msk_andr</a>
# <a href="queries.html?slice=ya-browser&amp;period=month">ya-browser</a>
# <a href="queries.html?slice=yahoo&amp;period=month">yahoo</a>
# <a href="queries.html?slice=barnaul&amp;period=month">barnaul</a>
# <a href="queries.html?slice=nnovgorod&amp;period=month">nnovgorod</a>
# <a href="queries.html?slice=tyumen&amp;period=month">tyumen</a>
# <a href="queries.html?slice=img.ya&amp;period=month">img.ya</a>
# <a href="queries.html?slice=iphone&amp;period=month">iphone</a>
# <a href="queries.html?slice=perm&amp;period=month">perm</a>
# <a href="queries.html?slice=cr-mail&amp;period=month">cr-mail</a>
# <a href="queries.html?slice=goo-chrome&amp;period=month">goo-chrome</a>
# <a href="queries.html?slice=ya-chrome&amp;period=month">ya-chrome</a>
# <a href="queries.html?slice=tomsk&amp;period=month">tomsk</a>
# <a href="queries.html?slice=orenburg&amp;period=month">orenburg</a>
# <a href="queries.html?slice=android&amp;period=month">android</a>
# <a href="queries.html?slice=kurgan&amp;period=month">kurgan</a>
# <a href="queries.html?slice=chel&amp;period=month">chel</a>
# <a href="queries.html?slice=krasnodar&amp;period=month">krasnodar</a>
# <a href="queries.html?slice=mini&amp;period=month">mini</a>
# <a href="queries.html?slice=ipad&amp;period=month">ipad</a>
# <a href="queries.html?slice=ffall&amp;period=month">ffall</a>
# <a href="queries.html?slice=ieall&amp;period=month">ieall</a>
# <a href="queries.html?slice=opera&amp;period=month">opera</a>
# <a href="queries.html?slice=saf&amp;period=month">saf</a>
# <a href="queries.html?slice=ie6&amp;period=month">ie6</a>
# <a href="queries.html?slice=ge&amp;period=month">ge</a>
# <a href="queries.html?slice=ufa&amp;period=month">ufa</a>
# <a href="queries.html?slice=chrome-ww&amp;period=month">chrome-ww</a>
# <a href="queries.html?slice=bing&amp;period=month">bing</a>
# <a href="queries.html?slice=qip&amp;period=month">qip</a>
# <a href="queries.html?slice=goo-ru&amp;period=month">goo-ru</a>
# <a href="queries.html?slice=chrome&amp;period=month">chrome</a>
# <a href="queries.html?slice=rus&amp;period=month">rus</a>
# <a href="queries.html?slice=by&amp;period=month">by</a>
# <a href="queries.html?slice=kz&amp;period=month">kz</a>
# <a href="queries.html?slice=liru&amp;period=month">liru</a>
# <a href="queries.html?slice=go.mail&amp;period=month">go.mail</a>
# <a href="queries.html?slice=spb&amp;period=month">spb</a>
# <a href="queries.html?slice=nigma&amp;period=month">nigma</a>
# <a href="queries.html?slice=vlad&amp;period=month">vlad</a>
# <a href="queries.html?slice=m1.yandex&amp;period=month">m1.yandex</a>
# <a href="queries.html?slice=Google&amp;period=month">Google</a>
# <a href="queries.html?slice=rambler&amp;period=month">rambler</a>
# <a href="queries.html?slice=yandex&amp;period=month">yandex</a>
# <a href="queries.html?slice=izr&amp;period=month">izr</a>
# <a href="queries.html?slice=ukr&amp;period=month">ukr</a>
# <a href="queries.html?slice=novosib&amp;period=month">novosib</a>
# <a href="queries.html?slice=kemer&amp;period=month">kemer</a>
# <a href="queries.html?slice=kalinin&amp;period=month">kalinin</a>
# <a href="queries.html?slice=ek&amp;period=month">ek</a>
# <a href="queries.html?slice=kazan&amp;period=month">kazan</a>
# <a href="queries.html?slice=ru&amp;period=month">ru</a>
# <a href="queries.html?slice=msk&amp;period=month">msk</a>
# </td>
# <tr>
# <td colspan="2"><table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td>
# </td>
# <td align="right"><a href="queries.html?period=month&amp;1818" title="обновить страницу">
# обновлено 13 апреля в 23:59</a></td></tr></table></td>
# </tr></tr></form></tr></table>
# <input name="period" type="hidden" value="month"/>
# <br/>
# <span id="banstat21_span"></span><hr/>
# <span id="rtm1" style="width:500px;"></span><br/>
# <span id="rtm2" style="width:500px;"></span>
# </td></tr></tr></tbody></table></center><table><tr><td height="10"></td></tr></table>
# <hr color="black" noshade="" size="1"/>
# <table border="0" cellpadding="0" cellspacing="0" width="520"><tr>
# <td align="left" width="33%"><a href="queries.html?date=2023-03-31&amp;period=month">&lt;&lt; Мар 23</a></td>
# <td align="center" width="33%"><b>апрель 2023 г.</b></td>
# <td align="right" width="33%"> </td>
# </tr></table>
# <hr color="black" noshade="" size="1"/>
# <p>
# <table border="0" cellpadding="0" cellspacing="0" width="520">
# <tr>
# <td><b>отчет:</b> переходы по поисковым фразам</td>
# <td align="right"><small>
# <a href="queries.html">по дням</a> |
# <a href="queries.html?period=week">по неделям</a> |
# <span class="bc6">по месяцам</span></small></td>
# </tr></table>
# <table bgcolor="#e8e8e8" border="0" cellpadding="3" cellspacing="0" width="520">
# <tr align="right" bgcolor="#f0f0f0">
# <td align="left" colspan="2">
# значения:<br/><b>среднесуточные</b> / <a href="queries.html?period=month&amp;total=yes">суммарные</a></td>
# <td colspan="2">апрель 2023 г.</td>
# <td colspan="2">март 2023 г.</td>
# <td colspan="2">в среднем<br/>за 3 месяца</td>
# <tr align="right" bgcolor="#dddddd">
# <td><input checked="" id="id_54197" name="id" type="checkbox" value="54197"/></td>
# <td align="left">
# <label for="id_54197">Другие</label>
# </td>
# <td>851,162</td><td><font size="-2">92.2%</font></td>
# <td>883,590</td><td><font size="-2">89.5%</font></td>
# <td>2,000</td><td><font size="-2">91.2%</font></td>
# <tr align="right">
# <td><input checked="" id="id_54204" name="id" type="checkbox" value="54204"/></td>
# <td align="left">
# <label for="id_54204"><a href="24hours.html?gosearchword=1&amp;search-word=%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D0%B8&amp;day_1=1">новости</a></label>
# </td>
# <td>5,467</td><td><font size="-2">0.6%</font></td>
# <td>6,848</td><td><font size="-2">0.7%</font></td>
# <td>16</td><td><font size="-2">0.7%</font></td>
# <tr align="right" bgcolor="#dddddd">
# <td><input checked="" id="id_58184" name="id" type="checkbox" value="58184"/></td>
# <td align="left">
# <label for="id_58184"><a href="24hours.html?gosearchword=1&amp;search-word=%D0%B3%D0%B0%D0%B7%D0%B5%D1%82%D0%B0%20%D1%87%D1%81%20%D0%BF%D0%BE%D1%81%D0%BB%D0%B5%D0%B4%D0%BD%D0%B8%D0%B9%20%D0%BD%D0%BE%D0%BC%D0%B5%D1%80&amp;day_1=1">газета чс последний номер</a></label>
# </td>
# <td>2,771</td><td><font size="-2">0.3%</font></td>
# <td>2,716</td><td><font size="-2">0.3%</font></td>
# <td>9.1</td><td><font size="-2">0.4%</font></td>
# <tr align="right">
# <td><input checked="" id="id_54280" name="id" type="checkbox" value="54280"/></td>
# <td align="left">
# <label for="id_54280"><a href="24hours.html?gosearchword=1&amp;search-word=%D0%BC%D0%B0%D0%B9%D0%BB%20%D1%80%D1%83&amp;day_1=1">майл ру</a></label>
# </td>
# <td>2,481</td><td><font size="-2">0.3%</font></td>
# <td>2,633</td><td><font size="-2">0.3%</font></td>
# <td>5.6</td><td><font size="-2">0.3%</font></td>
# <tr align="right" bgcolor="#dddddd">
# <td><input checked="" id="id_54240" name="id" type="checkbox" value="54240"/></td>
# <td align="left">
# <label for="id_54240"><a href="24hours.html?gosearchword=1&amp;search-word=%D0%BC%D0%B0%D0%B9%D0%BB&amp;day_1=1">майл</a></label>
# </td>
# <td>2,257</td><td><font size="-2">0.2%</font></td>
# <td>2,679</td><td><font size="-2">0.3%</font></td>
# <td>5.7</td><td><font size="-2">0.3%</font></td>
# <tr align="right">
# <td><input id="id_54859" name="id" type="checkbox" value="54859"/></td>
# <td align="left">
# <label for="id_54859"><a href="24hours.html?gosearchword=1&amp;search-word=%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D0%B8%20%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B8%20%D0%B8%20%D0%BC%D0%B8%D1%80%D0%B0%20%D1%81%D0%B5%D0%B3%D0%BE%D0%B4%D0%BD%D1%8F&amp;day_1=1">новости россии и мира сегодня</a></label>
# </td>
# <td>2,222</td><td><font size="-2">0.2%</font></td>
# <td>2,894</td><td><font size="-2">0.3%</font></td>
# <td>6.7</td><td><font size="-2">0.3%</font></td>
# <tr align="right" bgcolor="#dddddd">
# <td><input id="id_4843" name="id" type="checkbox" value="4843"/></td>
# <td align="left">
# <label for="id_4843"><a href="24hours.html?gosearchword=1&amp;search-word=mail.ru&amp;day_1=1">mail.ru</a></label>
# </td>
# <td>1,880</td><td><font size="-2">0.2%</font></td>
# <td>2,119</td><td><font size="-2">0.2%</font></td>
# <td>4.5</td><td><font size="-2">0.2%</font></td>
# <tr align="right">
# <td><input id="id_54450" name="id" type="checkbox" value="54450"/></td>
# <td align="left">
# <label for="id_54450"><a href="24hours.html?gosearchword=1&amp;search-word=%D1%81%D0%BC%D0%B82&amp;day_1=1">сми2</a></label>
# </td>
# <td>1,373</td><td><font size="-2">0.1%</font></td>
# <td>1,636</td><td><font size="-2">0.2%</font></td>
# <td>3.7</td><td><font size="-2">0.2%</font></td>
# <tr align="right" bgcolor="#dddddd">
# <td><input id="id_55045" name="id" type="checkbox" value="55045"/></td>
# <td align="left">
# <label for="id_55045"><a href="24hours.html?gosearchword=1&amp;search-word=%D1%80%D0%B0%D0%BC%D0%B1%D0%BB%D0%B5%D1%80&amp;day_1=1">рамблер</a></label>
# </td>
# <td>1,367</td><td><font size="-2">0.1%</font></td>
# <td>1,506</td><td><font size="-2">0.2%</font></td>
# <td>3.5</td><td><font size="-2">0.2%</font></td>
# <tr align="right">
# <td><input id="id_54717" name="id" type="checkbox" value="54717"/></td>
# <td align="left">
# <label for="id_54717"><a href="24hours.html?gosearchword=1&amp;search-word=%D1%81%D0%BF%D0%BE%D1%80%D1%82%D0%B1%D0%BE%D0%BA%D1%81&amp;day_1=1">спортбокс</a></label>
# </td>
# <td>1,101</td><td><font size="-2">0.1%</font></td>
# <td>1,098</td><td><font size="-2">0.1%</font></td>
# <td>2.2</td><td><font size="-2">0.1%</font></td>
# <tr><td bgcolor="#f0f0f0" colspan="8"><img alt="" height="1" src="//i.li.ru/i/_.gif" width="1"/></td>
# <tr align="right" bgcolor="#dddddd">
# <td><input id="id_checked" name="id" type="checkbox" value="checked"/></td>
# <td align="left">
# <label for="id_checked">сумма выбранных</label>
# </td>
# <td>864,139</td><td><font size="-2">93.6%</font></td>
# <td>898,466</td><td><font size="-2">91.0%</font></td>
# <td>2,037</td><td><font size="-2">92.9%</font></td>
# <tr align="right">
# <td><input id="id_total" name="id" type="checkbox" value="total"/></td>
# <td align="left">
# <label for="id_total">всего</label>
# </td>
# <td>922,928</td><td><font size="-2"> </font></td>
# <td>987,121</td><td><font size="-2"> </font></td>
# <td>2,194</td><td><font size="-2"> </font></td>
# <tr><td bgcolor="#ffffff" colspan="8"><input name="show" type="submit" value="перестроить график"/>
# </td>
# </tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></table>
# <p>Страницы: <span class="high current">1</span>  <a class="high" href="queries.html?period=month&amp;page=2">2</a> <a class="high" href="queries.html?period=month&amp;page=3">3</a> ... <a class="high" href="queries.html?period=month&amp;page=27">27</a> <a class="high" href="queries.html?period=month&amp;page=28">28</a> <br>
# «предыдущая | <a class="high" href="queries.html?period=month&amp;page=2">следующая</a>»
#
#
#
# Выводить по <select name="per_page">
# <option>10
# <option>20
# <option>50
# <option>100</option></option></option></option></select> строк на странице
# <input name="ok" type="submit" value=" OK "/><br/>
# <form><input name="rnd" type="hidden" value="367349667"/>
# <input name="period" type="hidden" value="month"/>
# <small>Фильтр:
# <select name="type">
# <option value="only">только
# <option value="except">кроме
# </option></option></select>
# <input name="filter" size="30" type="text" value=""/>
# <input name="ok" type="submit" value=" OK "/><br/>
# </small>
# <p>
# <span id="banstat22_span"></span>
# <!-- ru -->
# <span id="banstat23_span"></span>
# <p>
# <span id="rtm10" style="width:500px"></span>
# <br/>
# <span id="rtm9" style="width:500px;height=20px;"></span>
# <br/>
# <span id="rtm6" style="width:500px;height=20px;"></span>
# <a href="/go?www.liveinternet.ru/adt.cgi" target="_blank"><img border="0" height="17" src="/gg/clik.gif" widtg="500"/></a>
# <br/><br/>
# <table>
# <tr><td colspan="2"><img border="0" height="405" src="/i/s/10/1sstF8.png" usemap="#map" width="520"/>
# <map name="map"><area coords="472,302,513,317" href="queries.html?date=2023-04-13&amp;period=month" shape="rect"/>
# <area coords="429,313,470,325" href="queries.html?date=2023-01-31&amp;period=month" shape="rect"/>
# <area coords="388,302,427,314" href="queries.html?date=2022-10-31&amp;period=month" shape="rect"/>
# <area coords="344,313,387,325" href="queries.html?date=2022-07-31&amp;period=month" shape="rect"/>
# <area coords="301,302,342,317" href="queries.html?date=2022-04-30&amp;period=month" shape="rect"/>
# <area coords="259,313,300,325" href="queries.html?date=2022-01-31&amp;period=month" shape="rect"/>
# <area coords="219,302,256,314" href="queries.html?date=2021-10-31&amp;period=month" shape="rect"/>
# <area coords="174,313,215,325" href="queries.html?date=2021-07-31&amp;period=month" shape="rect"/>
# <area coords="132,302,171,317" href="queries.html?date=2021-04-30&amp;period=month" shape="rect"/>
# <area coords="89,313,128,325" href="queries.html?date=2021-01-31&amp;period=month" shape="rect"/>
# <area coords="48,302,87,314" href="queries.html?date=2020-10-31&amp;period=month" shape="rect"/>
# <area coords="68,291,9" href="queries.html?date=2020-10-31&amp;period=month" shape="circle" title="Окт 20: 21,081"/>
# <area coords="82,291,9" href="queries.html?date=2020-11-30&amp;period=month" shape="circle" title="Ноя 20: 20,173"/>
# <area coords="96,290,9" href="queries.html?date=2020-12-31&amp;period=month" shape="circle" title="Дек 20: 33,072"/>
# <area coords="110,291,9" href="queries.html?date=2021-01-31&amp;period=month" shape="circle" title="Янв 21: 25,054"/>
# <area coords="124,291,9" href="queries.html?date=2021-02-28&amp;period=month" shape="circle" title="Фев 21: 19,786"/>
# <area coords="139,292,9" href="queries.html?date=2021-03-31&amp;period=month" shape="circle" title="Мар 21: 13,539"/>
# <area coords="153,292,9" href="queries.html?date=2021-04-30&amp;period=month" shape="circle" title="Апр 21: 12,982"/>
# <area coords="167,292,9" href="queries.html?date=2021-05-31&amp;period=month" shape="circle" title="Май 21: 9,991"/>
# <area coords="181,292,9" href="queries.html?date=2021-06-30&amp;period=month" shape="circle" title="Июн 21: 9,917"/>
# <area coords="195,292,9" href="queries.html?date=2021-07-31&amp;period=month" shape="circle" title="Июл 21: 8,016"/>
# <area coords="209,292,9" href="queries.html?date=2021-08-31&amp;period=month" shape="circle" title="Авг 21: 5,036"/>
# <area coords="224,292,9" href="queries.html?date=2021-09-30&amp;period=month" shape="circle" title="Сен 21: 5,934"/>
# <area coords="238,292,9" href="queries.html?date=2021-10-31&amp;period=month" shape="circle" title="Окт 21: 5,118"/>
# <area coords="252,292,9" href="queries.html?date=2021-11-30&amp;period=month" shape="circle" title="Ноя 21: 5,185"/>
# <area coords="266,292,9" href="queries.html?date=2021-12-31&amp;period=month" shape="circle" title="Дек 21: 5,087"/>
# <area coords="280,292,9" href="queries.html?date=2022-01-31&amp;period=month" shape="circle" title="Янв 22: 4,300"/>
# <area coords="295,292,9" href="queries.html?date=2022-02-28&amp;period=month" shape="circle" title="Фев 22: 5,274"/>
# <area coords="309,292,9" href="queries.html?date=2022-03-31&amp;period=month" shape="circle" title="Мар 22: 5,261"/>
# <area coords="323,292,9" href="queries.html?date=2022-04-30&amp;period=month" shape="circle" title="Апр 22: 4,813"/>
# <area coords="337,292,9" href="queries.html?date=2022-05-31&amp;period=month" shape="circle" title="Май 22: 3,961"/>
# <area coords="351,292,9" href="queries.html?date=2022-06-30&amp;period=month" shape="circle" title="Июн 22: 4,230"/>
# <area coords="366,292,9" href="queries.html?date=2022-07-31&amp;period=month" shape="circle" title="Июл 22: 3,960"/>
# <area coords="380,292,9" href="queries.html?date=2022-08-31&amp;period=month" shape="circle" title="Авг 22: 4,102"/>
# <area coords="394,292,9" href="queries.html?date=2022-09-30&amp;period=month" shape="circle" title="Сен 22: 5,214"/>
# <area coords="408,292,9" href="queries.html?date=2022-10-31&amp;period=month" shape="circle" title="Окт 22: 4,772"/>
# <area coords="422,292,9" href="queries.html?date=2022-11-30&amp;period=month" shape="circle" title="Ноя 22: 2,817"/>
# <area coords="437,292,9" href="queries.html?date=2022-12-31&amp;period=month" shape="circle" title="Дек 22: 2,625"/>
# <area coords="451,292,9" href="queries.html?date=2023-01-31&amp;period=month" shape="circle" title="Янв 23: 2,360"/>
# <area coords="465,292,9" href="queries.html?date=2023-02-28&amp;period=month" shape="circle" title="Фев 23: 2,674"/>
# <area coords="479,292,9" href="queries.html?date=2023-03-31&amp;period=month" shape="circle" title="Мар 23: 2,679"/>
# <area coords="493,292,9" href="queries.html?date=2023-04-13&amp;period=month" shape="circle" title="Апр 23: 2,257"/>
# <area coords="68,292,9" href="queries.html?date=2020-10-31&amp;period=month" shape="circle" title="Окт 20: 13,286"/>
# <area coords="82,292,9" href="queries.html?date=2020-11-30&amp;period=month" shape="circle" title="Ноя 20: 12,328"/>
# <area coords="96,291,9" href="queries.html?date=2020-12-31&amp;period=month" shape="circle" title="Дек 20: 19,374"/>
# <area coords="110,291,9" href="queries.html?date=2021-01-31&amp;period=month" shape="circle" title="Янв 21: 16,781"/>
# <area coords="124,292,9" href="queries.html?date=2021-02-28&amp;period=month" shape="circle" title="Фев 21: 13,447"/>
# <area coords="139,292,9" href="queries.html?date=2021-03-31&amp;period=month" shape="circle" title="Мар 21: 8,919"/>
# <area coords="153,292,9" href="queries.html?date=2021-04-30&amp;period=month" shape="circle" title="Апр 21: 8,296"/>
# <area coords="167,292,9" href="queries.html?date=2021-05-31&amp;period=month" shape="circle" title="Май 21: 6,691"/>
# <area coords="181,292,9" href="queries.html?date=2021-06-30&amp;period=month" shape="circle" title="Июн 21: 6,638"/>
# <area coords="195,292,9" href="queries.html?date=2021-07-31&amp;period=month" shape="circle" title="Июл 21: 5,166"/>
# <area coords="209,292,9" href="queries.html?date=2021-08-31&amp;period=month" shape="circle" title="Авг 21: 3,803"/>
# <area coords="224,292,9" href="queries.html?date=2021-09-30&amp;period=month" shape="circle" title="Сен 21: 4,695"/>
# <area coords="238,292,9" href="queries.html?date=2021-10-31&amp;period=month" shape="circle" title="Окт 21: 4,206"/>
# <area coords="252,292,9" href="queries.html?date=2021-11-30&amp;period=month" shape="circle" title="Ноя 21: 4,038"/>
# <area coords="266,292,9" href="queries.html?date=2021-12-31&amp;period=month" shape="circle" title="Дек 21: 3,712"/>
# <area coords="280,292,9" href="queries.html?date=2022-01-31&amp;period=month" shape="circle" title="Янв 22: 3,230"/>
# <area coords="295,292,9" href="queries.html?date=2022-02-28&amp;period=month" shape="circle" title="Фев 22: 4,130"/>
# <area coords="309,292,9" href="queries.html?date=2022-03-31&amp;period=month" shape="circle" title="Мар 22: 4,078"/>
# <area coords="323,292,9" href="queries.html?date=2022-04-30&amp;period=month" shape="circle" title="Апр 22: 3,961"/>
# <area coords="337,292,9" href="queries.html?date=2022-05-31&amp;period=month" shape="circle" title="Май 22: 3,303"/>
# <area coords="351,292,9" href="queries.html?date=2022-06-30&amp;period=month" shape="circle" title="Июн 22: 3,554"/>
# <area coords="366,292,9" href="queries.html?date=2022-07-31&amp;period=month" shape="circle" title="Июл 22: 3,411"/>
# <area coords="380,292,9" href="queries.html?date=2022-08-31&amp;period=month" shape="circle" title="Авг 22: 3,641"/>
# <area coords="394,292,9" href="queries.html?date=2022-09-30&amp;period=month" shape="circle" title="Сен 22: 4,534"/>
# <area coords="408,292,9" href="queries.html?date=2022-10-31&amp;period=month" shape="circle" title="Окт 22: 4,093"/>
# <area coords="422,292,9" href="queries.html?date=2022-11-30&amp;period=month" shape="circle" title="Ноя 22: 2,799"/>
# <area coords="437,292,9" href="queries.html?date=2022-12-31&amp;period=month" shape="circle" title="Дек 22: 2,608"/>
# <area coords="451,292,9" href="queries.html?date=2023-01-31&amp;period=month" shape="circle" title="Янв 23: 2,458"/>
# <area coords="465,292,9" href="queries.html?date=2023-02-28&amp;period=month" shape="circle" title="Фев 23: 2,454"/>
# <area coords="479,292,9" href="queries.html?date=2023-03-31&amp;period=month" shape="circle" title="Мар 23: 2,633"/>
# <area coords="493,292,9" href="queries.html?date=2023-04-13&amp;period=month" shape="circle" title="Апр 23: 2,480"/>
# <area coords="68,293,9" href="queries.html?date=2020-10-31&amp;period=month" shape="circle" title="Окт 20: 0"/>
# <area coords="82,293,9" href="queries.html?date=2020-11-30&amp;period=month" shape="circle" title="Ноя 20: 0"/>
# <area coords="96,293,9" href="queries.html?date=2020-12-31&amp;period=month" shape="circle" title="Дек 20: 0"/>
# <area coords="110,293,9" href="queries.html?date=2021-01-31&amp;period=month" shape="circle" title="Янв 21: 0"/>
# <area coords="124,293,9" href="queries.html?date=2021-02-28&amp;period=month" shape="circle" title="Фев 21: 0"/>
# <area coords="139,293,9" href="queries.html?date=2021-03-31&amp;period=month" shape="circle" title="Мар 21: 0"/>
# <area coords="153,293,9" href="queries.html?date=2021-04-30&amp;period=month" shape="circle" title="Апр 21: 0"/>
# <area coords="167,293,9" href="queries.html?date=2021-05-31&amp;period=month" shape="circle" title="Май 21: 0"/>
# <area coords="181,293,9" href="queries.html?date=2021-06-30&amp;period=month" shape="circle" title="Июн 21: 0"/>
# <area coords="195,293,9" href="queries.html?date=2021-07-31&amp;period=month" shape="circle" title="Июл 21: 0"/>
# <area coords="209,293,9" href="queries.html?date=2021-08-31&amp;period=month" shape="circle" title="Авг 21: 0"/>
# <area coords="224,293,9" href="queries.html?date=2021-09-30&amp;period=month" shape="circle" title="Сен 21: 0"/>
# <area coords="238,293,9" href="queries.html?date=2021-10-31&amp;period=month" shape="circle" title="Окт 21: 0"/>
# <area coords="252,293,9" href="queries.html?date=2021-11-30&amp;period=month" shape="circle" title="Ноя 21: 0"/>
# <area coords="266,293,9" href="queries.html?date=2021-12-31&amp;period=month" shape="circle" title="Дек 21: 0"/>
# <area coords="280,293,9" href="queries.html?date=2022-01-31&amp;period=month" shape="circle" title="Янв 22: 0"/>
# <area coords="295,293,9" href="queries.html?date=2022-02-28&amp;period=month" shape="circle" title="Фев 22: 0"/>
# <area coords="309,293,9" href="queries.html?date=2022-03-31&amp;period=month" shape="circle" title="Мар 22: 0"/>
# <area coords="323,293,9" href="queries.html?date=2022-04-30&amp;period=month" shape="circle" title="Апр 22: 0"/>
# <area coords="337,293,9" href="queries.html?date=2022-05-31&amp;period=month" shape="circle" title="Май 22: 0"/>
# <area coords="351,293,9" href="queries.html?date=2022-06-30&amp;period=month" shape="circle" title="Июн 22: 0"/>
# <area coords="366,293,9" href="queries.html?date=2022-07-31&amp;period=month" shape="circle" title="Июл 22: 0"/>
# <area coords="380,293,9" href="queries.html?date=2022-08-31&amp;period=month" shape="circle" title="Авг 22: 0"/>
# <area coords="394,293,9" href="queries.html?date=2022-09-30&amp;period=month" shape="circle" title="Сен 22: 0"/>
# <area coords="408,293,9" href="queries.html?date=2022-10-31&amp;period=month" shape="circle" title="Окт 22: 0"/>
# ...
# <area coords="266,292,9" href="queries.html?date=2021-12-31&amp;period=month" shape="circle" title="Дек 21: 4,150"/>
# <area coords="280,292,9" href="queries.html?date=2022-01-31&amp;period=month" shape="circle" title="Янв 22: 4,493"/>
# <area coords="295,292,9" href="queries.html?date=2022-02-28&amp;period=month" shape="circle" title="Фев 22: 6,872"/>
# <area coords="309,292,9" href="queries.html?date=2022-03-31&amp;period=month" shape="circle" title="Мар 22: 8,368"/>
# <area coords="323,292,9" href="queries.html?date=2022-04-30&amp;period=month" shape="circle" title="Апр 22: 6,858"/>
# <area coords="337,292,9" href="queries.html?date=2022-05-31&amp;period=month" shape="circle" title="Май 22: 4,940"/>
# <area coords="351,292,9" href="queries.html?date=2022-06-30&amp;period=month" shape="circle" title="Июн 22: 4,050"/>
# <area coords="366,292,9" href="queries.html?date=2022-07-31&amp;period=month" shape="circle" title="Июл 22: 4,275"/>
# <area coords="380,292,9" href="queries.html?date=2022-08-31&amp;period=month" shape="circle" title="Авг 22: 4,118"/>
# <area coords="394,292,9" href="queries.html?date=2022-09-30&amp;period=month" shape="circle" title="Сен 22: 10,194"/>
# <area coords="408,292,9" href="queries.html?date=2022-10-31&amp;period=month" shape="circle" title="Окт 22: 11,918"/>
# <area coords="422,292,9" href="queries.html?date=2022-11-30&amp;period=month" shape="circle" title="Ноя 22: 8,715"/>
# <area coords="437,292,9" href="queries.html?date=2022-12-31&amp;period=month" shape="circle" title="Дек 22: 7,719"/>
# <area coords="451,292,9" href="queries.html?date=2023-01-31&amp;period=month" shape="circle" title="Янв 23: 7,872"/>
# <area coords="465,292,9" href="queries.html?date=2023-02-28&amp;period=month" shape="circle" title="Фев 23: 8,534"/>
# <area coords="479,292,9" href="queries.html?date=2023-03-31&amp;period=month" shape="circle" title="Мар 23: 6,847"/>
# <area coords="493,292,9" href="queries.html?date=2023-04-13&amp;period=month" shape="circle" title="Апр 23: 5,466"/>
# <area coords="68,97,9" href="queries.html?date=2020-10-31&amp;period=month" shape="circle" title="Окт 20: 2,962,718"/>
# <area coords="82,80,9" href="queries.html?date=2020-11-30&amp;period=month" shape="circle" title="Ноя 20: 3,223,751"/>
# <area coords="96,81,9" href="queries.html?date=2020-12-31&amp;period=month" shape="circle" title="Дек 20: 3,199,467"/>
# <area coords="110,89,9" href="queries.html?date=2021-01-31&amp;period=month" shape="circle" title="Янв 21: 3,076,528"/>
# <area coords="124,57,9" href="queries.html?date=2021-02-28&amp;period=month" shape="circle" title="Фев 21: 3,574,709"/>
# <area coords="139,62,9" href="queries.html?date=2021-03-31&amp;period=month" shape="circle" title="Мар 21: 3,491,701"/>
# <area coords="153,60,9" href="queries.html?date=2021-04-30&amp;period=month" shape="circle" title="Апр 21: 3,522,539"/>
# <area coords="167,85,9" href="queries.html?date=2021-05-31&amp;period=month" shape="circle" title="Май 21: 3,146,192"/>
# <area coords="181,104,9" href="queries.html?date=2021-06-30&amp;period=month" shape="circle" title="Июн 21: 2,855,068"/>
# <area coords="195,121,9" href="queries.html?date=2021-07-31&amp;period=month" shape="circle" title="Июл 21: 2,604,159"/>
# <area coords="209,114,9" href="queries.html?date=2021-08-31&amp;period=month" shape="circle" title="Авг 21: 2,697,016"/>
# <area coords="224,72,9" href="queries.html?date=2021-09-30&amp;period=month" shape="circle" title="Сен 21: 3,342,541"/>
# <area coords="238,120,9" href="queries.html?date=2021-10-31&amp;period=month" shape="circle" title="Окт 21: 2,620,758"/>
# <area coords="252,135,9" href="queries.html?date=2021-11-30&amp;period=month" shape="circle" title="Ноя 21: 2,382,444"/>
# <area coords="266,149,9" href="queries.html?date=2021-12-31&amp;period=month" shape="circle" title="Дек 21: 2,172,034"/>
# <area coords="280,166,9" href="queries.html?date=2022-01-31&amp;period=month" shape="circle" title="Янв 22: 1,912,335"/>
# <area coords="295,165,9" href="queries.html?date=2022-02-28&amp;period=month" shape="circle" title="Фев 22: 1,932,029"/>
# <area coords="309,172,9" href="queries.html?date=2022-03-31&amp;period=month" shape="circle" title="Мар 22: 1,832,262"/>
# <area coords="323,182,9" href="queries.html?date=2022-04-30&amp;period=month" shape="circle" title="Апр 22: 1,680,189"/>
# <area coords="337,196,9" href="queries.html?date=2022-05-31&amp;period=month" shape="circle" title="Май 22: 1,459,818"/>
# <area coords="351,199,9" href="queries.html?date=2022-06-30&amp;period=month" shape="circle" title="Июн 22: 1,421,842"/>
# <area coords="366,206,9" href="queries.html?date=2022-07-31&amp;period=month" shape="circle" title="Июл 22: 1,311,695"/>
# <area coords="380,204,9" href="queries.html?date=2022-08-31&amp;period=month" shape="circle" title="Авг 22: 1,343,485"/>
# <area coords="394,196,9" href="queries.html?date=2022-09-30&amp;period=month" shape="circle" title="Сен 22: 1,457,479"/>
# <area coords="408,194,9" href="queries.html?date=2022-10-31&amp;period=month" shape="circle" title="Окт 22: 1,491,123"/>
# <area coords="422,226,9" href="queries.html?date=2022-11-30&amp;period=month" shape="circle" title="Ноя 22: 1,003,272"/>
# <area coords="437,233,9" href="queries.html?date=2022-12-31&amp;period=month" shape="circle" title="Дек 22: 908,952"/>
# <area coords="451,229,9" href="queries.html?date=2023-01-31&amp;period=month" shape="circle" title="Янв 23: 961,197"/>
# <area coords="465,229,9" href="queries.html?date=2023-02-28&amp;period=month" shape="circle" title="Фев 23: 960,914"/>
# <area coords="479,234,9" href="queries.html?date=2023-03-31&amp;period=month" shape="circle" title="Мар 23: 883,589"/>
# <area coords="493,236,9" href="queries.html?date=2023-04-13&amp;period=month" shape="circle" title="Апр 23: 851,162"/>
# </map>
# </td>
# <tr valign="top"><td><small>
# <a href="queries.html?period=month&amp;relgraph=yes">показать график относительных значений</a><br/>
# <a href="queries.html?period=month&amp;nograph=yes">убрать график</a><br/>
# <a href="queries.html?period=month&amp;graph=table" target="_blank">показать таблицу значений</a>
# (<a href="queries.csv?period=month&amp;graph=csv" target="_blank">csv</a> | <a href="queries.tsv?period=month&amp;graph=tsv" target="_blank">tsv</a>)<br/>
# <!--<a href="queries.html?period=month&graph=zoom">увеличить график</a><br>-->
# </small></td>
# <td align="right"><small><a href="queries.gif?period=month&amp;graph=yes" target="_blank" title="вы можете использовать эту ссылку для вставки картинки графика на свои страницы">ссылка на график</a><br/>
# </small></td>
# </tr></tr></table>
# <br/><br/>
# <span id="rtm7" style="width:500px;"></span>
# <p>
# <span id="rtm8" style="width:500px;"></span>
# <p>
# <span id="rtm5" style="width:500px;"></span>
# <a href="/go?www.liveinternet.ru/adt.cgi" target="_blank"><img border="0" height="17" src="/gg/clik.gif" widtg="500"/></a>
# <br/>
# <table border="0" cellpadding="3" cellspacing="0" width="500">
# <td>
# <hr color="black" noshade="" size="1"/>
# [<a href="queries.html?period=month&amp;nohelp=yes">убрать справку</a>]
# <p>
# Извините, данный раздел справок еще не готов.
#
# </p></td></table>
# <p>
# <!--баннер на схеме размещения не значится, стоит в самом низу, после справки-->
# <table border="1" cellpadding="0" cellspacing="0" width="520">
# <tr>
# <td align="center" bgcolor="gray" height="30"><select name="report" onchange="go(this)" style="height=12px; font: 12px; width=150px;">
# <optgroup label="Отчеты статистики">
# <optgroup label="Аудитория">
# <option value="index.html?period=month">посещаемость</option>
# <option value="hours.html?period=month">по времени суток</option>
# <option value="online.html?period=month">online</option>
# <option value="sum.html?period=month">за неделю и месяц</option>
# </optgroup>
# <optgroup label="Аудитория">
# <option value="visitors.html?period=month">размер аудитории</option>
# <option value="days_pw.html?period=month">дней в неделю</option>
# <option value="days_pm.html?period=month">дней в месяц</option>
# <option value="compare.html?period=month">сравнение аудиторий</option>
# <option value="sessions_pv.html?period=month">сессий на посетителя</option>
# <option value="returns.html?period=month">возвраты</option>
# <option value="hits_pv.html?period=month">просм. на посетителя</option>
# <option value="hits_ps.html?period=month">просмотров за сессию</option>
# <option value="durations.html?period=month">длительность сессий</option>
# </optgroup>
# <optgroup label="Просмотры">
# <option value="servers.html?period=month">варианты обращения</option>
# </optgroup>
# <optgroup label="Переходы">
# <option value="catalogs.html?period=month">из каталогов и рейтингов</option>
# <option value="mails.html?period=month">почтовые сервисы</option>
# <option value="socials.html?period=month">из социальных сетей</option>
# <option value="searches.html?period=month">из поисковых систем</option>
# <option selected="" value="queries.html?period=month">по поисковым фразам</option>
# <option value=""> </option>
# <option value="clicks.html?period=month">переходы по ссылкам</option>
# </optgroup>
# <optgroup label="О посетителях">
# <option value="demo.html?period=month">демография</option>
# <option value="countries.html?period=month">страны</option>
# <option value="countries_hits.html?period=month">страны (просмотры)</option>
# <option value="regions.html?period=month">регионы России</option>
# <option value="regions_hits.html?period=month">регионы (просмотры)</option>
# <option value="languages.html?period=month">языки</option>
# <option value="browsers.html?period=month">браузеры</option>
# <option value="oses.html?period=month">ОС</option>
# <option value="resolutions.html?period=month">разрешение</option>
# <option value="colors.html?period=month">кол-во цветов</option>
# </optgroup>
# </optgroup>
# <option value="summary.html?period=month">сводка</option>
# <option value=""> </option>
# <option value="edit.html?period=month">изменение описания</option>
# <option value="logout.html?period=month">выход</option>
# </select></td>
# </tr>
# </table>
# <p>
# <table border="0" cellpadding="5" cellspacing="0" width="520">
# <td>
# Для владельца сайта:
# <!--<a href="http://www.liveinternet.ru/pay/">оплата сервиса</a>&nbsp;&nbsp;-->
# <a href="edit.html">изменить описание сайта</a>
# <a href="/code?nick=ru">html-код счетчика</a>
# <a href="logout.html">выход</a><br/>
# </td>
#
# </table>
#
# <td width="10"> </td>
# <td valign="top" width="240">
# <table><td align="left">
# <a href="/add"><b>регистрация</b></a>
# <p></p></td></table></td></p></p></p></p></p></p></form>
# <form action="/stat/" autocomplete="off" method="post">Статистика сайта:<br/>
# <input autocomplete="off" maxlength="100" name="url" onfocus="this.removeAttribute('readonly')" placeholder="Адрес" readonly="" size="16" type="text" value=""/><br/>
# <input autocomplete="off" maxlength="20" name="password" placeholder="Пароль" size="12" type="password"/> <input name="ok" type="submit" value="&gt;"/><br/>
# <a href="/stat/?what=reset-password">Забыли или не знаете пароль?</a>
# </form>
#
# <p>
# <span id="banstat31_span"></span>
# <div style="width:240px; height:400px; margin:0; overflow:hidden;">
# <!--AdFox START-->
# <!--MarTi-->
# <!--Площадка: liveinternet.ru / * / *-->
# <!--Тип баннера: Side-->
# <!--Расположение: 1-->
# <div id="adfox_side1"></div></div>
# <script>
#     window.Ya.adfoxCode.create({
#         ownerId: 254948,
#         containerId: 'adfox_side1',
#         params: {
#             pp: 'noj',
#             ps: 'erxe',
#             p2: 'fvyf',
#             puid1: '',
#             puid2: '',
#             puid3: ''
#         }
#     });
# </script>
# <script>
#     window.Ya.adfoxCode.create({
#         ownerId: 315450,
#         containerId: 'liveinternet_240x400s1',
#         params: {
#             p1: 'cfywh',
#             p2: 'gmgx',
#             puid1: '',
#             puid2: '',
#             puid3: ''}});
# </script>
# <p>
# <p>
# <hr/>
# <br/>
# <span id="rtm3" style="width:200px;"></span>
# <p>
# <span id="rtm4" style="width:200px;"></span>
# <p>
# <br/>
# <hr/>
# <span id="banstat32_span"></span>
# <hr/>
# <p>
# <!--iframe src="/cgi-bin/adv.fcgi?p=11,12,17,13,15,16&span-name=banstat11_span,banstat12_span,banstat23_span,banstat21_span,banstat31_span,banstat32_span&qtype=iframe,parent" style="position:absolute;top:0;left:0;width:1px;height:1px;visibility:hidden; border:0px outset;" scrolling=no frameborder=no></iframe>
# !--＞
# <!--
#
# <span id=banstat35_span></span>
#
# <iframe src="/cgi-bin/adv.fcgi?p=11,12,14,13,15,16&span-name=banstat11_span,banstat12_span,banstat22_span,banstat21_span,banstat31_span,banstat32_span&qtype=iframe,parent" style="position:absolute;top:0;left:0;width:1;height:1;visibility:hidden; border:0px outset;" scrolling=no frameborder=no></iframe>
#
#
# -->
# <p>
# <div id="adfox_side2" style="width: 240px; height: 400px;"></div>
# <!--AdFox START-->
# <!--MarTi-->
# <!--Площадка: liveinternet.ru / * / *-->
# <!--Тип баннера: Side-->
# <!--Расположение: 2-->
# <script>
#     window.Ya.adfoxCode.create({
#         ownerId: 254948,
#         containerId: 'adfox_side2',
#         params: {
#             pp: 'nok',
#             ps: 'erxe',
#             p2: 'fvyf',
#             puid1: '',
#             puid2: '',
#             puid3: ''
#         }
#     });
# </script>
#
#
#
# <script language="JavaScript"><!--
# function adt_design(span_name,url,text,meaning) {
#     if (span_name=='rtm8')
#         return "<table border=0 cellspacing=2 cellpadding=2 bgcolor=#003300><tr><td> <a style='text-decoration:none' href='"+url+"' target=_blank><font color=white size=+1 title='"+meaning+"'><b>"+text+"</b></font></a></td></tr></table>";
#     if (span_name=='rtm9')
#         return "<table border=0 cellspacing=2 cellpadding=2 bgcolor=#ff9900><tr><td> <a style='text-decoration:none' href='"+url+"' target=_blank><font color=black size=+1 title='"+meaning+"'><b>"+text+"</b></font></a></td></tr></table>";
#     return "<table border=0 cellspacing=0 cellpadding=0><tr><td> <a href='"+url+"' target=_blank><font color=blue title='"+meaning+"'><b>"+text+"</b></font></a></td></tr></table>";
# }
# //--></script>
# <iframe frameborder="no" scrolling="no" src="/cgi-bin/adt.fcgi?p=1&amp;count=10&amp;span-name=rtm&amp;function-name=adt_design&amp;qtype=parent,iframe&amp;text-size=110" style="visibility:hidden; width:1px; height:1px; border:0px outset;"></iframe>
# <form></form>
# <hr color="black" size="1" width="970"/>
# <table border="0" cellpadding="0" cellspacing="0" width="965"><tr>
# <td align="left">
# Служба поддержки: <a href="mailto:counter@corp.liveinternet.ru">counter@corp.liveinternet.ru</a>
# <!--<span style="padding:0 10 0 10">&bull;</span>
# <a href="http://mastertalk.ru/forum13.html">форум</a>-->
# <span style="padding:0 10px 0 10px">•</span>
# <a href="/ad/">размещение рекламы</a>
# <!--— Yandex.Metrika counter —-->
# <script type="text/javascript">
#     (function (d, w, c) {
#         (w[c] = w[c] || []).push(function() {
#             try {
#                 w.yaCounter11963701 = new Ya.Metrika({
#                     id:11963701,
#                     clickmap:true,
#                     trackLinks:true,
#                     accurateTrackBounce:true
#                 });
#             } catch(e) { }
#         });
#
#         var n = d.getElementsByTagName("script")[0],
#             s = d.createElement("script"),
#             f = function () { n.parentNode.insertBefore(s, n); };
#         s.type = "text/javascript";
#         s.async = true;
#         s.src = "https://mc.yandex.ru/metrika/watch.js";
#
#         if (w.opera == "[object Opera]") {
#             d.addEventListener("DOMContentLoaded", f, false);
#         } else { f(); }
#     })(document, window, "yandex_metrika_callbacks");
# </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/11963701" style="position:absolute; left:-9999px;"/></div></noscript>
# <!--— /Yandex.Metrika counter —-->
# <td align="right">
# <!--LiveInternet logo--><a href="http://www.liveinternet.ru/click" target="_blank"><img alt="" border="0" height="15" src="//counter.yadro.ru/logo?23.2" title="LiveInternet: показано число посетителей за сегодня" width="88"/></a><!--/LiveInternet-->
# </td></td></tr></table>
# </p></p></p></p></p></p></p></br></p></p></body></html>

# %% [markdown]
# Нужные данные зашиты в тег `<a>` с классом `high`, найдем их все:

# %%
soup_pages = soup.find_all('a', class_='high')
soup_pages
# Out:
# [<a class="high" href="queries.html?period=month&amp;page=2">2</a>,
#  <a class="high" href="queries.html?period=month&amp;page=3">3</a>,
#  <a class="high" href="queries.html?period=month&amp;page=27">27</a>,
#  <a class="high" href="queries.html?period=month&amp;page=28">28</a>,
#  <a class="high" href="queries.html?period=month&amp;page=2">следующая</a>]

# %% [markdown]
# Получили перечень страниц, номера которых видно в представлении на сайте. Нужно выбрать максимальное значение - это и будет последняя страница.
# Извлечем текст из тега `<a>` и соберем его в список:

# %%
pages_num = []
for i in soup_pages:
    num = i.contents
    pages_num.append(num)

# %%
pages_num
# Out:
# [['2'], ['3'], ['27'], ['28'], ['следующая']]

# %% [markdown]
# Нужный нам номер всегда будет предпоследним элементом в списке. Задаем его как границу диапазона страниц:

# %%
last_page = pages_num[-2]

# %% [markdown]
# Номера страниц были получены как строки, преобразуем номер в числовой формат:

# %%
last_page = [int(x) for x in last_page][0]

# %% [markdown]
# Подставляем полученный номер в диапазон страниц, не забыв добавить единицу, т.к. нумерация начинается с 0:

# %%
pages = list(range(1,last_page+1))

# %% [markdown]
# Также нужно учесть то, что по умолчанию на странице отображаются среднесуточные значения. Для большей информативности потребуются суммарные. Это переключатель, но судя по коду страницы он вложен в таблицу просто ссылкой с параметром `total=yes`:
#
# `<a href="queries.html?period=month&amp;total=yes">суммарные</a>`
#
# Но зато, если посмотреть на ссылку в адресной строке, то видно, что при выборе варианта "суммарные" адрес ссылки меняется: к ней добавляется `&total=yes`. Добавим такой параметр к нашей заготовке ссылки.

# %% [markdown]
# Теперь можно парсить таблицы.
# Создадим пустой датафрейм и поочередно прибавим к нему каждую полученную со страницы таблицу.

# %%
query_stats = pd.DataFrame()

# %%
for i in pages:
    url_pages = "https://www.liveinternet.ru/stat/ru/queries.html?period=month&total=yes&page=" + str(i)
    stats = pd.read_html(url_pages, encoding='utf-8')[5]
    query_stats = pd.concat([query_stats,stats], ignore_index=True)

# %%
query_stats
# Out:
#                                        0                                    1  \
# 0    значения:суммарные / среднесуточные  значения:суммарные / среднесуточные
# 1                                    NaN                               Другие
# 2                                    NaN                              новости
# 3                                    NaN            газета чс последний номер
# 4                                    NaN                              майл ру
# ..                                   ...                                  ...
# 412                                  NaN                       купить apecoin
# 413                                  NaN                                  NaN
# 414                                  NaN                      сумма выбранных
# 415                                  NaN                                всего
# 416                                  NaN                                  NaN
#
#                   2               3             4             5  \
# 0    апрель 2023 г.  апрель 2023 г.  март 2023 г.  март 2023 г.
# 1          11065112           92.2%      27391283         89.5%
# 2             71069            0.6%        212279          0.7%
# 3             36029            0.3%         84210          0.3%
# 4             32251            0.3%         81623          0.3%
# ..              ...             ...           ...           ...
# 412             170            0.0%             0          0.0%
# 413             NaN             NaN           NaN           NaN
# 414             902            0.0%          5354          0.0%
# 415        11998065             NaN      30600753           NaN
# 416             NaN             NaN           NaN           NaN
#
#                         6                     7
# 0    в среднемза 3 месяца  в среднемза 3 месяца
# 1                21787331                 91.2%
# 2                  174103                  0.7%
# 3                   99340                  0.4%
# 4                   60865                  0.3%
# ..                    ...                   ...
# 412                    56                  0.0%
# 413                   NaN                   NaN
# 414                  7765                  0.0%
# 415              23890890                   NaN
# 416                   NaN                   NaN
#
# [417 rows x 8 columns]

# %% [markdown]
# Пока не обращаем внимания на то, что дублируются первые столбцы в таблице. Это произошло из-за того, что на сайте в первом столбце расположен элемент выбора - флаг, соответственно он не распознается. Этот столбец удалим позже, когда соберем все данные. Также на каждой странице внизу выводилась сумма выбранных - это количество запросов, которые были отмечены активным флагом, и всего - это общее количество запросов на странице. Такие строки также нужно будет удалить, как и полностью пустые строки. Это будет сделано на этапе предобработки.

# %% [markdown]
# Получили данные о поисковых запросах за текущий месяц. Для целей исследования понадобятся данные также за более ранние периоды. На сайте возможно только три варианта отображения данных: по дням, по неделям и по месяцам, причем переходить к более ранним периодам можно только последовательно по кнопке.
# Посмотрим, как в коде прописан переход к предущему месяцу (Март 2023):

# %% [markdown]
# `<td align="left" width="33%"><a href="queries.html?date=2023-03-31&amp;period=month">&lt;&lt; Мар 23</a></td>`

# %% [markdown]
# Это ссылка, к которой добавляется дата - последнее число нужного месяца. То есть для получения данных за требуемые периоды, нужно научить парсер генерировать строку со ссылкой, в которой будет последовательно изменяться дата.

# %% [markdown]
# Создадим объект типа `Series` с интересующими датами для последующего перебора:

# %%
dates = np.array(['2023-04-30','2023-03-31', '2023-02-28', '2023-01-31',
                 '2022-12-31', '2022-11-30', '2022-10-31', '2022-09-30', '2022-08-31', '2022-07-31', '2022-06-30',
                 '2022-05-31', '2022-04-30', '2022-03-31', '2022-02-28', '2022-01-31',
                 '2021-12-31', '2021-11-30', '2021-10-31', '2021-09-30', '2021-08-31', '2021-07-31', '2021-06-30',
                 '2021-05-31', '2021-04-30', '2021-03-31', '2021-02-28', '2021-01-31'])

# %%
dates = pd.Series(dates)

# %% [markdown]
# Данные в столбце с датами строковые, что пока удобно, т.к. нужно будет подставлять их в строку. Но также потребуется создать два дополнительных столбца - с месяцем и годом, для того, чтобы можно было отслеживать динамику.
# Данные за апрель уже получены, но добавим к диапазону дату в таком же формате `2023-04-30`, чтобы получить все данные в одной таблице.

# %% [markdown]
# ## Полный код парсера и сбор данных

# %% [markdown]
# Формируем пустой датафрейм, к которому будем присоединять таблицы:

# %%
query_stats_previous = pd.DataFrame()

# %% [markdown]
# Собираем парсер. В указанном диапазоне дат запускаем цикл, который будет последовательно подставлять и менять дату в адресе ссылки на дату из диапазона. Для каждой такой страницы будем получать html-структуру и находить в ней тег с номерами страниц. Затем по описанной ранее логике переберем все страницы с данными внутри выбранного месяца и сохраним таблицу с каждой страницы:

# %%
for i in dates:
#     ссылка на страницу с перебором дат и получение кода страницы
    url_previous = 'https://www.liveinternet.ru/stat/ru/queries.html?date={}&amp;period=month&total=yes&page='.format(i)
    r = rq.get(url_previous)
    soup = bs(r.text, 'html.parser')
    soup_pages = soup.find_all('a', class_='high')
#     список видимых страниц
    pages_num = []
#     перебор страниц и извлечение номера последней страницы в выбранном месяце
    for j in soup_pages:
        num = j.contents
        pages_num.append(num)
    last_page = pages_num[-2]
    last_page = [int(x) for x in last_page][0]
#     создание диапазона страниц внутри выбранного месяца
    pages = list(range(1,last_page+1))
#     получение таблицы с данными с каждой страницы
    for k in pages:
        url_pages = url_previous + str(k)
        stats = pd.read_html(url_pages, encoding='utf-8')[5]
#         добавление столбца с датой, извлечение месяца и года
        stats['period'] = pd.to_datetime(i)
        stats['month'] = stats['period'].dt.month
        stats['year'] = stats['period'].dt.year
#         соединение таблиц
        query_stats_previous = pd.concat([query_stats_previous,stats], ignore_index=True)

# %%
query_stats_previous.head()
# Out:
#                                      0                                    1  \
# 0  значения:суммарные / среднесуточные  значения:суммарные / среднесуточные
# 1                                  NaN                               Другие
# 2                                  NaN                              новости
# 3                                  NaN            газета чс последний номер
# 4                                  NaN                              майл ру
#
#                 2               3             4             5  \
# 0  апрель 2023 г.  апрель 2023 г.  март 2023 г.  март 2023 г.
# 1        11065112           92.2%      27391283         89.5%
# 2           71069            0.6%        212279          0.7%
# 3           36029            0.3%         84210          0.3%
# 4           32251            0.3%         81623          0.3%
#
#                       6                     7     period  month  year
# 0  в среднемза 3 месяца  в среднемза 3 месяца 2023-04-30      4  2023
# 1              21787331                 91.2% 2023-04-30      4  2023
# 2                174103                  0.7% 2023-04-30      4  2023
# 3                 99340                  0.4% 2023-04-30      4  2023
# 4                 60865                  0.3% 2023-04-30      4  2023

# %% [markdown]
# Установим первую строку в качестве наименований столбцов и сбросим индексы:

# %%
query_stats_previous = query_stats_previous.rename(columns=query_stats_previous.iloc[0])

# %%
query_stats_previous = query_stats_previous.reindex(query_stats_previous.index.drop(0))

# %%
query_stats_previous.head()
# Out:
#   значения:суммарные / среднесуточные значения:суммарные / среднесуточные  \
# 1                                 NaN                              Другие
# 2                                 NaN                             новости
# 3                                 NaN           газета чс последний номер
# 4                                 NaN                             майл ру
# 5                                 NaN                                майл
#
#   апрель 2023 г. апрель 2023 г. март 2023 г. март 2023 г.  \
# 1       11065112          92.2%     27391283        89.5%
# 2          71069           0.6%       212279         0.7%
# 3          36029           0.3%        84210         0.3%
# 4          32251           0.3%        81623         0.3%
# 5          29342           0.2%        83063         0.3%
#
#   в среднемза 3 месяца в среднемза 3 месяца 2023-04-30 00:00:00  4  2023
# 1             21787331                91.2%          2023-04-30  4  2023
# 2               174103                 0.7%          2023-04-30  4  2023
# 3                99340                 0.4%          2023-04-30  4  2023
# 4                60865                 0.3%          2023-04-30  4  2023
# 5                62428                 0.3%          2023-04-30  4  2023

# %%
query_stats_previous.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3235 entries, 1 to 3235
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   значения:суммарные / среднесуточные  222 non-null    object
#  1   значения:суммарные / среднесуточные  2789 non-null   object
#  2   апрель 2023 г.                       2789 non-null   object
#  3   апрель 2023 г.                       2566 non-null   object
#  4   март 2023 г.                         2789 non-null   object
#  5   март 2023 г.                         2566 non-null   object
#  6   в среднемза 3 месяца                 2789 non-null   object
#  7   в среднемза 3 месяца                 2566 non-null   object
#  8   2023-04-30 00:00:00                  3235 non-null   datetime64[ns]
#  9   4                                    3235 non-null   int64
#  10  2023                                 3235 non-null   int64
# dtypes: datetime64[ns](1), int64(2), object(8)
# memory usage: 303.3+ KB

# %% [markdown]
# Сохраняем полученный датасет для дальнейшего исследования:

# %%
query_stats_previous.to_csv('query_stats.csv')

# %% [markdown]
# Датасет готов, после предобработки можно использовать его для анализа.
